# %%
import sys
sys.path.append(r'C:\Users\ADITI SONKUSARE\Desktop\nuscenes-devkit-master\python-sdk\nuscenes')

# %%
from nuscene import NuScene

nusc = NuScene(version='v1.0-mini', dataroot=r'C:/Users/ADITI SONKUSARE/Desktop/THESIS/Dataset/', verbose=True)
print(nusc)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24900\2405767540.py in <module>
# ----> 1 from nuscene import NuScene
#       2
#       3 nusc = NuScene(version='v1.0-mini', dataroot=r'C:/Users/ADITI SONKUSARE/Desktop/THESIS/Dataset/', verbose=True)
#       4 print(nusc)
#
# ImportError: cannot import name 'NuScene' from 'nuscene' (C:\Users\ADITI SONKUSARE\Desktop\nuscenes-devkit-master\python-sdk\nuscenes\nuscene.py)

# %%
my_sample = nusc.sample[2]

# %%
points= nusc.render_pointcloud_in_image(my_sample['token'], pointsensor_channel='RADAR_BACK_LEFT', camera_channel = 'CAM_BACK_LEFT')

# %%
type(points)
# Out:
# NoneType
